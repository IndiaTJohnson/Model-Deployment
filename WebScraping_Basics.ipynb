# %%
import pandas as pd

# %%
url = "https://worldpopulationreview.com/state-rankings/average-temperatures-by-state"

# %%
tables = pd.read_html(url)

# %%
df = tables[0]

# %%
df
# Out:
#              State  Average Temperature (F)  Average Temperature (C)  \
# 0          Florida                     70.7                     21.5
# 1           Hawaii                     70.0                     21.1
# 2        Louisiana                     66.4                     19.1
# 3            Texas                     64.8                     18.2
# 4          Georgia                     63.5                     17.5
# 5      Mississippi                     63.4                     17.4
# 6          Alabama                     62.8                     17.1
# 7   South Carolina                     62.4                     16.9
# 8         Arkansas                     60.4                     15.8
# 9          Arizona                     60.3                     15.7
# 10        Oklahoma                     59.6                     15.3
# 11      California                     59.4                     15.2
# 12  North Carolina                     59.0                     15.0
# 13       Tennessee                     57.6                     14.2
# 14        Kentucky                     55.6                     13.1
# 15        Delaware                     55.3                     12.9
# 16        Virginia                     55.1                     12.8
# 17        Missouri                     54.5                     12.5
# 18          Kansas                     54.3                     12.4
# 19        Maryland                     54.2                     12.3
# 20      New Mexico                     53.4                     11.9
# 21      New Jersey                     52.7                     11.5
# 22        Illinois                     51.8                     11.0
# 23   West Virginia                     51.8                     11.0
# 24         Indiana                     51.7                     10.9
# 25            Ohio                     50.7                     10.4
# 26    Rhode Island                     50.1                     10.1
# 27          Nevada                     49.9                      9.9
# 28     Connecticut                     49.0                      9.4
# 29        Nebraska                     48.8                      9.3
# 30    Pennsylvania                     48.8                      9.3
# 31            Utah                     48.6                      9.2
# 32          Oregon                     48.4                      9.1
# 33      Washington                     48.3                      9.1
# 34   Massachusetts                     47.9                      8.8
# 35            Iowa                     47.8                      8.8
# 36        New York                     45.4                      7.4
# 37    South Dakota                     45.2                      7.3
# 38        Colorado                     45.1                      7.3
# 39           Idaho                     44.4                      6.9
# 40        Michigan                     44.4                      6.9
# 41   New Hampshire                     43.8                      6.6
# 42       Wisconsin                     43.1                      6.2
# 43         Vermont                     42.9                      6.1
# 44         Montana                     42.7                      5.9
# 45         Wyoming                     42.0                      5.6
# 46       Minnesota                     41.2                      5.1
# 47           Maine                     41.0                      5.0
# 48    North Dakota                     40.4                      4.7
# 49          Alaska                     26.6                     -3.0
#
#     Avg. Annual Precipitation (in)  Average High (F)  Average Low (F)
# 0                             54.4              81.9             60.9
# 1                             43.2              80.4             66.6
# 2                             59.7              77.5             56.7
# 3                             28.6              78.1             53.5
# 4                             50.4              75.6             52.7
# 5                             58.5              75.3             53.0
# 6                             56.9              75.0             52.2
# 7                             48.3              74.7             52.0
# 8                             52.5              71.8             50.2
# 9                             11.6              75.3             46.8
# 10                            36.4              72.3             48.3
# 11                            22.3              71.5             46.5
# 12                            50.8              70.5             48.6
# 13                            55.1              69.4             47.5
# 14                            50.4              67.2             45.4
# 15                            45.9              66.1             46.3
# 16                            45.8              66.9             45.1
# 17                            43.5              66.0             44.5
# 18                            29.0              67.5             42.6
# 19                            45.2              65.4             45.4
# 20                            13.8              69.5             39.4
# 21                            47.6              63.6             43.6
# 22                            40.7              62.7             42.6
# 23                            47.1              63.5             41.7
# 24                            43.6              62.5             42.2
# 25                            41.1              61.7             41.6
# 26                            49.1              60.0             41.3
# 27                            10.2              64.6             37.4
# 28                            48.7              60.0             39.8
# 29                            24.2              61.9             36.9
# 30                            45.0              59.7             39.2
# 31                            13.5              62.0             36.4
# 32                            32.1              59.4             36.4
# 33                            43.2              57.0             37.6
# 34                            48.6              58.8             38.7
# 35                            35.6              58.5             38.1
# 36                            43.5              55.9             36.1
# 37                            21.2              57.5             33.8
# 38                            18.0              60.0             32.4
# 39                            23.7              55.7             32.1
# 40                            33.9              55.0             35.3
# 41                            47.9              54.7             33.3
# 42                            34.1              54.0             33.7
# 43                            46.0              53.4             32.7
# 44                            18.9              54.7             30.4
# 45                            16.0              55.2             29.3
# 46                            28.6              51.9             31.4
# 47                            45.5              51.9             31.7
# 48                            18.8              52.2             29.8
# 49                            37.6              35.5             20.4

# %%
import statistics as st

# %%
median = st.median(df["Average Temperature (F)"])

# %%
median
# Out:
# 51.2
